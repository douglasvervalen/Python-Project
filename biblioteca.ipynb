# %%
import numpy as np
from colored import fg, attr, bg
from time import sleep
maracutaia = True
if maracutaia:
    red = fg(196)
    blue = fg(27)
    cyan = fg(39)
    green = fg(34)
    lemon = fg(82)
    pink = fg(198)
    white = fg(15)
    yellow = fg(226)
    orange = fg(214)
    gray = fg(241)
    purple = fg(93)
    ocean = fg(29)
    wine = fg(88)
    lava = fg(208)
    bege = fg(223)
    pad1 = orange
    res = attr(0)
    bold = attr(1)
    sub = attr(7)
    rsub = attr(27)

#Most important function:
def hello_world():
    print(f'{lava}Hello World ')
    print(f'{blue}Hello World ')
    print(f'{cyan}Hello World ')
    print(f'{green}Hello World ')
    print(f'{lemon}Hello World ')
    print(f'{pink}Hello World ')
    print(f'{orange}Hello World ')
    print(f'{purple}Hello World ')

#Cria uma matriz 2d
def criar_matriz():
    while True:
        tamanho = input(f"{white}{bold}Tamanho da Matriz no formato (linha coluna): {res}").split()
        if len(tamanho) == 2:
            l, c = [int(value) for value in tamanho]
            matrix = np.zeros((l,c))
            t = 0
            i = 0
            counter = 0
            while i < l:
                x = input(f'{white}{bold}Linha {counter+1} : {res}').split()
                if len(x) == c:
                    for j in range(0, 2):
                        matrix[t, 0:c+1:1] = x
                    t += 1
                    i += 1
                    counter += 1
                else:
                    print(f'{red}{bold}Entrada Inválida!!!')
                    print(f'Número de colunas entrado não compátivel com os da matriz')
                    print(f'Valor Entrado {white}{len(x)} {red}Tamanho da Matriz {white}{c}{res}')
                    if counter == t:
                        i = t
            return matrix
            break
        else:
            print(f'{red}{bold}Entrada Inválida!!!')
            print(f'Tamanho da Matriz deve ser indicado por (Linha Coluna) || Ex: {white}(3 3){res}')
#Cria um vetor de n dimensões
def criar_vetor():
    while True:
        y = input(f'{white}{bold}Tamanho do vetor: {res}').split()
        dimension = [int(value) for value in y]
        if len(dimension) == 1:
            dimensão = dimension[0]
            vetor = np.zeros((1,dimensão))
            i = 0
            while i < 1:
                x = input(f'{white}{bold}Elementos do vetor: {res}').split()
                if len(x) == dimensão:
                    for i in range(0,2):
                        vetor[0,0:dimensão:1] = x
                    i += 1
                    realvetor = vetor.flatten()
                    return realvetor
                    break
                else:
                    print(f'{red}{bold}Entrada Inválida!!!')
                    print(f'Números de elementos entrado não compátivel com o tamanho do vetor')
                    print(f'Valor Entrado {white}{len(x)} {red}Tamanho do Vetor {white}{dimensão}{res}')
        else:
            print(f'{red}{bold}Entrada Inválida!!!')
            print(f'Tamanho do vetor inválido{res}')
#Cria um vetor com tamanho definido (1,3)
def criar_vetor_3():
    dimensão = 3
    vetor = np.zeros((1,dimensão))
    i = 0
    while i < 1:
        x = input(f'{white}{bold}Elementos do vetor no formato (x y z): {res}')
        x = x.split()
        if len(x) == dimensão:
            for i in range(0,2):
                vetor[0,0:dimensão:1] = x
            i += 1
            realvetor = vetor.flatten()
            return realvetor
            break
        else:
            print(f'{red}{bold}Entrada Inválida!!!')
            print(f'Números de elementos entrado não compátivel com o tamanho do vetor')
            print(f'Valor Entrado {white}{len(x)} {red}Tamanho do Vetor {white}{dimensão}{res}')
#Cria uma matriz quadrada
def criar_matriz_sqr():
    while True:
        y = input(f"{white}{bold}Tamanho da Matriz: {res}").split()
        dimensao = [int(value) for value in y]
        if len(dimensao) == 1:
            tamanho = dimensao[0]
            matrix = np.identity(tamanho)
            t = 0
            i = 0
            counter = 0
            while i < tamanho:
                x = input(f'{white}{bold}{counter+1} Linha: {res}').split()
                if len(x) == tamanho:
                    for j in range(0, 2):
                        matrix[t, 0:tamanho+1:1] = x
                    t += 1
                    i += 1
                    counter += 1
                else:
                    print(f'{red}{bold}Entrada Inválida!!!')
                    print(f'Número de colunas não compátivel com os da matriz')
                    print(f'Valor Entrado {white}{len(x)} {red}Tamanho da Matriz {white}{tamanho}.')
                    if counter == t:
                        i = t
            return matrix
            break
        else:
            print(f'{red}{bold}Entrada Inválida!!!')
            print(f'Tamanho da matriz inválida{res}')

#Geometria Ánalitica
#Faz o produto escalar entre 2 vetores
def produto_escalar():
    while True:
        print(f"{orange}{bold}-=-=(Vetor A)=-=-{res}")
        a = criar_vetor()
        dim = a.size
        print(f"{cyan}{bold}-=-=(Vetor B)=-=-{res}")
        b = criar_vetor_copy(dim)
        multvetor = a * b
        result = sum(multvetor)
        return result
        break
#Faz o produto vetorial entre 2 vetores
def produto_vetorial():
    while True:
        print(f"{cyan}{bold}-=-=(Vetor A)=-=-{res}")
        a = criar_vetor_3()
        print(f"{pink}{bold}-=-=(Vetor B)=-=-{res}")
        b = criar_vetor_3()
        vetor = np.cross(a, b)
        return vetor
        break
#Faz o produto misto entre 3 vetores
def produto_misto():
    print(f"{blue}{bold}-=-=(Vetor u)=-=-{res}")
    u = criar_vetor_3()
    print(f"{lava}{bold}-=-=(Vetor v)=-=-{res}")
    v = criar_vetor_3()
    print(f"{green}{bold}-=-=(Vetor w)=-=-{res}")
    w = criar_vetor_3()
    uvw = np.zeros((3,3))
    vetores = [u, v, w]
    c = 0
    for i in range(0,3):
        for j in range(0,2):
            uvw[c, 0:4:1] = vetores[c]
        c += 1
    result = determinante_copy(uvw)
    return result

#Algebra Linear
#Acha a determinante de uma matriz
def determinante():
    a = criar_matriz_sqr()
    result = np.linalg.det(a)
    return result
#Acha a matriz inversa
def matriz_inversa():
    a = criar_matriz_sqr()
    b = determinante_copy(a)
    if b != 0:
        result = np.linalg.inv(a)
        return result
    else:
        print(f'{red}{bold}Matriz inválida!!!')
        print(f'Matriz não admite inversa')
#Acha a solução de um sistema
def soluçao_do_sistema():
    while True:
        x = (input(f'{white}{bold}Número de equações do sistema: {res}')).split()
        verify = [int(value) for value in x]
        recipiente = []
        count = 0
        if len(verify) == 1:
            tamanho = verify[0]
            while count < tamanho:
                for i in range(tamanho):
                    y = input(f'{white}{bold}Coeficientes da equação {i+1}:{res} ').split()
                    coef = [float(values) for values in y]
                    recipiente.append(coef)
                for k in range(tamanho):
                    if len(recipiente[0]) == len(recipiente[k - 1]):
                        count += 1
                    else:
                        count -= 1
                        print(f'{red}{bold}As seguintes equações possuem o número de coeficientes diferentes {white}{recipiente[0]} {red}e {white}{recipiente[k - 1]}{res}')
                if count < tamanho:
                    recipiente.clear()
            equaçoes = np.asarray(recipiente)
            gambiarra = np.zeros((tamanho, tamanho))
            if equaçoes.shape == gambiarra.shape:
                sol = determinante_copy(equaçoes)
                if sol != 0:
                    index = 0
                    recipiente2 = []
                    while index < tamanho:
                        x2 = input(f'{white}{bold}Termo Independete da Equação {index+1}{res}: ').split()
                        ti = [float(values2) for values2 in x2]
                        if len(ti) == 1:
                            y2 = ti[0]
                            recipiente2.append(y2)
                            index += 1
                        else:
                            print(f'{red}{bold}Entrada Inválida!!!{res}')
                    termoindependente = np.asarray(recipiente2)
                    resultado = np.linalg.solve(equaçoes, termoindependente)
                    return resultado
                    break
                else:
                    print(f'{red}{bold}Sistema Impossível ou Possível e Indeterminado{res}')
            else:
                print(f'{red}{bold}Sistema entrado não compátivel!!!')
                print(f'Por favor! entrar com um sistema do tipo: "2x2, 3x3, 4x4, nxn"{res}')
        else:
            print(f'{red}{bold}Entrada Inválida!!!{res}')

#Cria cópias de funções com o parâmetro definido
def criar_vetor_copy(x):
    vetor = np.zeros((1,x))
    i = 0
    while i < 1:
        x = input(f'{white}{bold}Elementos do vetor: {res}').split()
        if len(x) == vetor.size:
            for i in range(0,2):
                vetor[0,0:vetor.size:1] = x
            i += 1
            realvetor = vetor.flatten()
            return realvetor
            break
        else:
            print(f'{red}{bold}Entrada Inválida!!!')
            print(f'Números de elementos entrado não compátivel com o tamanho do vetor')
            print(f'Valor Entrado {white}{len(x)} {red}Tamanho do Vetor {white}{vetor.size}{res}')
def produto_escalar_copy(x, y):
    while True:
        multvetor = x * y
        result = sum(multvetor)
        return result
        break
def determinante_copy(x):
    a = np.linalg.det(x)
    return a
def matriz_inversa_copy(x):
    b = determinante_copy(x)
    if b != 0:
        result = np.linalg.inv(x)
        return result
    else:
        print(f'{red}{bold}Matriz inválida!!!')
        print(f'Matriz não admite inversa{res}')

#Regressão Linear
def mmq():
    while True:
        x1 = input(f'{white}{bold}Valores de X: {res}')
        if x1 == 'q' or x1 == 'Q':
            loading()
            print(f'{bold}{red}Operação Cancelada!{res}')
            break
        else:
            x1 = x1.split()
            x_value = [float(value) for value in x1]
        y1 = input(f'{white}{bold}Valores de Y: {res}').split()
        y_value = [float(values) for values in y1]

        x = np.array(x_value)
        y = np.array(y_value)

        if len(x) == len(y):
            x_med = np.sum(x)
            x_med = x_med / (len(x))
            y_med = np.sum(y)
            y_med = y_med / (len(y))
            dx_list = []
            dy_list = []
            for i in range(len(x)):
                n = x[i] - x_med
                dx_list.append(n)
            for j in range(len(x)):
                m = y[j] - y_med
                dy_list.append(m)
            dx = np.array(dx_list)
            dy = np.array(dy_list)
            dx_dy = dx * dy
            sum_dxdy = np.sum(dx_dy)
            x_sqr_list = []
            for k in range(len(dx)):
                r = dx[k] * dx[k]
                x_sqr_list.append(r)
            x_sqr = np.array(x_sqr_list)
            sum_x_sqr = np.sum(x_sqr)
            coeficiente = sum_dxdy / sum_x_sqr
            intercep = y_med - (coeficiente * x_med)
            loading()
            print(f'{bold}{lemon}Coef. Angular: {white}{coeficiente}, {cyan}Coef. Linear: {white}{intercep:}{res}')
            break

        elif len(x) < len(y):
            print(f'{bold}{red}Quantidade de pontos não compatível {white}x {red}< {white}y')
            print(f'({red}x: {white}{len(x)}, {red}y: {white}{len(y)}){res}')

        elif len(x) > len(y):
            print(f'{bold}{red}Quantidade de pontos não compatível {white}y {red}< {white}x')
            print(f'({red}x: {white}{len(x)}, {red}y: {white}{len(y)}){res}')

#Achar Raizes:
def raiz_grau2():
    while True:
        coef = input(f'{bold}{white}Coeficientes na forma (a b c): {res}').split()
        x_list = [float(values) for values in coef]
        x = np.array(x_list)
        if len(x) == 3:
            delta = (x[1] * x[1]) - (4 * x[0] * x[2])
            if delta > 0:
                delta = delta ** 0.5
                x1 = (-x[1] + delta) / (2 * x[0])
                x2 = (-x[1] - delta) / (2 * x[0])
                print(f'{bold}{white}({x1}, {x2}){res}')
                result = x1, x2
            elif delta == 0:
                x1 = (-x[1]) / (2 * x[0])
                print(f'{bold}{white}{x1}{res}')
                result = x1
            else:
                print(f'{bold}{red}Não possui raiz Real{res}')
                result = 'Não'
            return result
        else:
            print(f'{bold}{red}Entrada Inválida!{res}')

#loading
def loading():
    for ç in range(8):
        print(f'{bold}{gray}-=-', end='', flush=True)
        sleep(0.03)
        print(f'{bold}{gray}=-', end='', flush=True)
    print(f'{res}', end='\n')

#Title
def title(text):
    print(f'{bold}{sub}{text}{res}')
#Tecla
def title2(title,text):
    print(f'{bold}{cyan}{title} {pad1}[{white} {text} {pad1}]{res}')

#Seletor
def seletor():
    while True:
        sleep(0.3)
        title2('Produto Vetorial', 'V')
        title2('Produto Escalar', 'E')
        title2('Produto Misto', 'M')
        title2('Solução de Sistemas', 'S')
        title2('Determinante', 'D')
        title2('Matriz Inversa', 'I')
        title2('Regressão Linear - MMQ', 'R')
        title2('Equação 2° Grau', '2')
        title2('Sair', 'Q')
        x = input(f'{bold}{white}Operação: {res}').lower().replace(' ', '')
        if x == 'v' or x == 'produtovetorial' or x == 'vetorial':
            loading()
            title('Produto Vetorial')
            loading()
            a = produto_vetorial()
            loading()
            print(f'{white}{bold}{lemon}Vetor AxB{white}: {a} {orange}[{white} x  y  z {orange}]{res}')
            loading()
        elif x == 'e' or x == 'produtoescalar' or x == 'escalar':
            loading()
            title('Produto Escalar')
            loading()
            b = produto_escalar()
            loading()
            print(f'{white}{bold}{b}{res}')
            loading()
        elif x == 'm' or x == 'produtomisto' or x == 'misto':
            loading()
            title('Produto Misto')
            loading()
            c = produto_misto()
            loading()
            print(f'{bege}{bold}{c}{res}')
            loading()
        elif x == 's' or x == 'sistemas' or x == 'soluçaodesistemas' or x == 'sistema':
            loading()
            title('Solução de Sistemas')
            loading()
            d = soluçao_do_sistema()
            loading()
            print(f'{white}{bold}{d}{res}')
            loading()
        elif x == 'd' or x == 'determinante' or x == 'det':
            loading()
            title('Determinante')
            loading()
            e = determinante()
            loading()
            print(f'{white}{bold}{lemon}Determinante{white}: {e}{res}')
            loading()
        elif x == 'i' or x == 'matrizinversa' or x == 'inversa':
            loading()
            title('Matriz Inversa')
            loading()
            f = matriz_inversa()
            loading()
            print(f'{white}{bold}{f}{res}')
            loading()
        elif x == 'r' or x == 'mmq':
            loading()
            title('Regressão Linear - MMQ')
            loading()
            mmq()
            loading()
        elif x == '2' or x == 'segundograu' or x == 'raiz':
            loading()
            title('Equação 2° Grau')
            loading()
            raiz_grau2()
            loading()
        elif x == 'q':
            break
        else:
            loading()
            print(f'{bold}{red}Entrada Inválida!{res}')
            loading()

if __name__ == '__main__':
    seletor()
